# %%
# %matplotlib inline
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from collections import defaultdict
from __future__ import division

# %%
### Chemical Data
chem_data = defaultdict(dict)
with open('data/smarts_stats_30.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        chem_data['30'][v] = int(k)
with open('data/smarts_stats_60.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        chem_data['60'][v] = int(k)
with open('data/smarts_stats_100.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        chem_data['100'][v] = int(k)
with open('data/smarts_stats_200.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        chem_data['200'][v] = int(k)
with open('data/smarts_stats_400.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        chem_data['400'][v] = int(k)
with open('data/1000_out_2.txt') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        chem_data['1000'][v] = int(k)
with open('data/random_2000.out') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        chem_data['2000'][v] = int(k)

        
### English data
eng_data = defaultdict(dict)
with open('data/en_stats_30.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        eng_data['30'][v] = int(k)
with open('data/en_stats_60.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        eng_data['60'][v] = int(k)
with open('data/en_stats_100.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        eng_data['100'][v] = int(k)
with open('data/en_stats_200.tsv') as f:
    for i in f.readlines():
        k,v = i.strip('\n').split('\t')
        eng_data['200'][v] = int(k)
with open('data/en_stats_400.tsv') as f:
    for i in f.readlines():
        k,v =i.strip('\n').split('\t')
        eng_data['400'][v] = int(k)
with open('data/en_stats_1000.tsv') as f:
    for i in f.readlines():
        k,v =i.strip('\n').split('\t')
        eng_data['1000'][v] = int(k)
with open('data/en_stats_2000.tsv') as f:
    for i in f.readlines():
        k,v =i.strip('\n').split('\t')
        eng_data['2000'][v] = int(k)

# %%
final = defaultdict(dict)
i = "30"
tmp = chem_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['chem_data'] = test
tmp = eng_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['eng_data'] = test
final[i]['color'] = '#B28F00'

i = "60"
tmp = chem_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['chem_data'] = test
tmp = eng_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['eng_data'] = test
final[i]['color'] = '#009300'

i = "100"
tmp = chem_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['chem_data'] = test
tmp = eng_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['eng_data'] = test
final[i]['color'] = '#66CCFF'

i = "200"
tmp = chem_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['chem_data'] = test
tmp = eng_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['eng_data'] = test
final[i]['color'] = '#993399'

i = "400"
tmp = chem_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['chem_data'] = test
tmp = eng_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['eng_data'] = test
final[i]['color'] = '#19A3A3'

i = "1000"
tmp = chem_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['chem_data'] = test
tmp = eng_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['eng_data'] = test
final[i]['color'] = '#CC6600'

i = "2000"
tmp = chem_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['chem_data'] = test
tmp = eng_data[i]
test = sorted(tmp.values(), reverse = True)
t = sum(test)
test = [j/t for j in test]
final[i]['eng_data'] = test
final[i]['color'] = '#4C4C4C'



#for i in data:
#    tmp = data[i]
#    test = sorted(tmp.values(), reverse = True)
#    test = [j/test[0] for j in test]
#    final[i] = test

# %%
mpl.rc('xtick', labelsize=22) 
mpl.rc('ytick', labelsize=22) 
mpl.rcParams.update({'font.size': 22, 'font.weight' : 'bold'})
fig= plt.figure(figsize=(14, 8))
ax = fig.add_subplot(1,1,1)
plt.yscale('log')
plt.xscale('log')
#ax.yaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
#ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
#ax.set_xlabel("Rank of fragment")
#ax.set_ylabel("Probability")
ax.set_xlim(1,50000)
ax.set_ylim(0.0000001,0.1)
ax.tick_params('both', length=20, width=2, which='major')
ax.tick_params('both', length=10, width=1, which='minor')
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

i = "2000"
y = final[i]['chem_data']
x = range(1,len(y)+1)
ax.plot(x,y,'o',label=i, markeredgewidth=0.00, markersize=5, alpha=0.7, color=final[i]['color'])
y = final[i]['eng_data']
x = range(1,len(y)+1)
ax.plot(x,y,'x',label=i, markersize=5, alpha = 0.7,color=final[i]['color'])

i = "1000"
y = final[i]['chem_data']
x = range(1,len(y)+1)
ax.plot(x,y,'o',label=i, markeredgewidth=0.00, markersize=5, alpha=0.7, color=final[i]['color'])
y = final[i]['eng_data']
x = range(1,len(y)+1)
ax.plot(x,y,'x',label=i, markersize=5, alpha = 0.7,color=final[i]['color'])

i = "400"
y = final[i]['chem_data']
x = range(1,len(y)+1)
ax.plot(x,y,'o',label=i, markeredgewidth=0.00, markersize=5, alpha=0.7, color=final[i]['color'])
y = final[i]['eng_data']
x = range(1,len(y)+1)
ax.plot(x,y,'x',label=i, markersize=5, alpha = 0.7,color=final[i]['color'])

i = "200"
y = final[i]['chem_data']
x = range(1,len(y)+1)
ax.plot(x,y,'o',label=i, markeredgewidth=0.00, markersize=5, alpha=0.7, color=final[i]['color'])
y = final[i]['eng_data']
x = range(1,len(y)+1)
ax.plot(x,y,'x',label=i, markersize=5, alpha = 0.7,color=final[i]['color'])

i = "100"
y = final[i]['chem_data']
x = range(1,len(y)+1)
ax.plot(x,y,'o',label=i, markeredgewidth=0.00, markersize=5, alpha=0.7, color=final[i]['color'])
y = final[i]['eng_data']
x = range(1,len(y)+1)
ax.plot(x,y,'x',label=i, markersize=5, alpha = 0.7,color=final[i]['color'])

i = "60"
y = final[i]['chem_data']
x = range(1,len(y)+1)
ax.plot(x,y,'o',label=i, markeredgewidth=0.00, markersize=5, alpha=0.7, color=final[i]['color'])
y = final[i]['eng_data']
x = range(1,len(y)+1)
ax.plot(x,y,'x',label=i, markersize=5, alpha = 0.7,color=final[i]['color'])

i = "30"
y = final[i]['chem_data']
x = range(1,len(y)+1)
ax.plot(x,y,'o',label=i, markeredgewidth=0.00, markersize=5, alpha=0.7, color=final[i]['color'])
y = final[i]['eng_data']
x = range(1,len(y)+1)
ax.plot(x,y,'x',label=i, markersize=5, alpha = 0.7,color=final[i]['color'])

fig.savefig("f_1.png", transparent=True)


#for i in final:
#    y = final[i]['chem_data']
#    x = range(1,len(y)+1)
#    ax.plot(x,y,'o',label=i, markeredgewidth=0.00, markersize=5, alpha=0.3, color=final[i]['color'])
#    y = final[i]['eng_data']
#    x = range(1,len(y)+1)
#    ax.plot(x,y,'x',label=i, markersize=5, alpha = 0.3,color=final[i]['color'])
